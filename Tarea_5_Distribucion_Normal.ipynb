# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxGarnica/Trabajos_SimulacionII/blob/Tareas/Tarea_5_Distribucion_Normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Maximiliano Garnica López*
#
# *Tarea 5*
#
# *Simulación II*

# %%
import random   
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Generaremos una distribución normal por el método de las doce uniformes utilizando la funcion $random()$ para generar un histograma.
#
# Utilizaremos la formula:
#
# $x=μ+σ[(𝚺_i^{12} R_i)-6]$
#
# con los valores de la media $μ=180$ y desviacion estandar $σ=15$
#
# $x=180+15[(𝚺_i^{12} R_i)-6]$

# %%
t=2000
mu=180
sigma=15
x=[]

for i in range(t):
  r=0
  for j in range (12):
    r_1=random.random()
    r=r+r_1

  x_1=mu+sigma*(r-6)
  x.append(x_1)

fig = plt.figure(1, figsize=(8, 8))        
plt.hist(x, color="magenta", bins=200)
plt.grid()
plt.show()

# %% [markdown]
# Ahora apliquemos la funcion $gauss()$ para comparar los histogramas.

# %%
mu=180
sigma=15
xg=[]

for i in range(t):
    xg_1=random.gauss(mu,sigma)
    xg.append(xg_1)

fig = plt.figure(1, figsize=(8, 8)) 
plt.hist(xg,bins=200)
plt.show()

# %% [markdown]
# Graficando los dos histogramas en usa sola grafica.

# %%
fig = plt.figure(1, figsize=(8, 8)) 
plt.hist(xg,bins=200)
plt.hist(x,color="magenta", bins=200)
plt.show()

# %% [markdown]
# Los dos histogramas son muy parecidos.
